# %% [markdown]
# <a href="https://colab.research.google.com/github/bamirotemitayo-hash/Assignment/blob/main/Code_1_2410MSC061.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CODE1
println(1.1 + 0.1)
# Out:
# 1.2000000000000002

# %%
#CODE2
f(x) = (1 - cos(x)) / x^2

x = range(-5, 5, length=100)
y = f.(x)   # broadcasting over the array

xi = (1e-5, 1e-6, 1e-7, 1e-8, 1e-9, 1e-10, 1e-11)

for x in xi
    println("f($x) = ", f(x))
end
# Out:
# f(1.0e-5) = 0.5000000413701854
# f(1.0e-6) = 0.5000444502911705
# f(1.0e-7) = 0.4996003610813205
# f(1.0e-8) = 0.0
# f(1.0e-9) = 0.0
# f(1.0e-10) = 0.0
# f(1.0e-11) = 0.0

# %%
#CODE3
x = 1.0
while 1.0 + x != 1.0
    x = x / 2.0
end

EPS = 2.0 * x
println("EPS = ", EPS)
println("x = ", x)
# Out:
# EPS = 2.220446049250313e-16
# x = 1.1102230246251565e-16
